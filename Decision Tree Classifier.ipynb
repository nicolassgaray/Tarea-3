# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv('water_potability.csv')
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# ...            ...             ...              ...        ...         ...
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [3276 rows x 10 columns]

# %%
df = df.fillna(df.mean())

# %% [markdown]
# # 1) Gini Coefficient, None, None

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'gini',
                                 max_depth = None,
                                 max_features = None)

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.5848595848595849

# %%
max_depth = reg.tree_.max_depth

print(f'La profundidad máxima del árbol es {max_depth}.')
# Out:
# La profundidad máxima del árbol es 27.

# %% [markdown]
# # 2) Gini Coefficient, 15, None

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'gini',
                                 max_depth = 15,
                                 max_features = None)

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.5995115995115995

# %% [markdown]
# # 3) Gini Coefficient, 7, None

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'gini',
                                 max_depth = 7,
                                 max_features = None)

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.6227106227106227

# %% [markdown]
# # 4) Gini Coefficient, None, Square Root

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'gini',
                                 max_depth = None,
                                 max_features = 'sqrt')

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.5628815628815629

# %% [markdown]
# # 5) Gini Coefficient, 15, Square Root

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'gini',
                                 max_depth = 15,
                                 max_features = 'sqrt')

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.6178266178266179

# %% [markdown]
# # 6) Gini Coefficient, 7, Square Root

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'gini',
                                 max_depth = 7,
                                 max_features = 'sqrt')

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.6202686202686203

# %% [markdown]
# # 7) Gini Coefficient, None, Log2()

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'gini',
                                 max_depth = None,
                                 max_features = 'log2')

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.5555555555555556

# %% [markdown]
# # 8) Gini Coefficient, 15, Log2()

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'gini',
                                 max_depth = 15,
                                 max_features = 'log2')

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.6043956043956044

# %% [markdown]
# # 9) Gini Coefficient, 7, Log2()

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'gini',
                                 max_depth = 7,
                                 max_features = 'log2')

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.6178266178266179

# %% [markdown]
# # 10) Entropy, None, None

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'entropy',
                                 max_depth = None,
                                 max_features = None)

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.590964590964591

# %% [markdown]
# # 11) Entropy, 15, None

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'entropy',
                                 max_depth = 15,
                                 max_features = None)

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.6214896214896215

# %% [markdown]
# # 12) Entropy, 7, None

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'entropy',
                                 max_depth = 7,
                                 max_features = None)

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.6178266178266179

# %% [markdown]
# # 13) Entropy, None, Square Root

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'entropy',
                                 max_depth = None,
                                 max_features = 'sqrt')

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.6019536019536019

# %% [markdown]
# # 14) Entropy, 15, Square Root

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'entropy',
                                 max_depth = 15,
                                 max_features = 'sqrt')

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.6056166056166056

# %% [markdown]
# # 15) Entropy, 7, Square Root

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'entropy',
                                 max_depth = 7,
                                 max_features = 'sqrt')

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.6251526251526252

# %% [markdown]
# # 16) Entropy, None, Log2()

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'entropy',
                                 max_depth = None,
                                 max_features = 'log2')

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.5811965811965812

# %% [markdown]
# # 17) Entropy, 15, Log2()

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'entropy',
                                 max_depth = 15,
                                 max_features = 'log2')

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.5970695970695971

# %% [markdown]
# # 18) Entropy, 7, Log2()

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
reg = DecisionTreeClassifier(criterion = 'entropy',
                                 max_depth = 7,
                                 max_features = 'log2')

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()
plt.xticks([0, 1], ['No Potable', 'Potable'])
plt.yticks([0, 1], ['No Potable', 'Potable'])
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Real')
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f'{cm[i, j]}', ha='center', va='center', color='black' if cm[i, j] > thresh else 'black')

plt.show()

# %%
acierto = accuracy_score(y_test, y_pred)
acierto
# Out:
# 0.6275946275946276

# %%
predict = reg.feature_importances_
predictore = pd.DataFrame({'Predictor': x.columns, 'Importancia': predict})
predictore = predictore.sort_values(by='Importancia', ascending=False)
predictore
# Out:
#          Predictor  Importancia
# 4          Sulfate     0.285641
# 0               ph     0.184654
# 3      Chloramines     0.142127
# 2           Solids     0.107640
# 5     Conductivity     0.099082
# 6   Organic_carbon     0.073006
# 1         Hardness     0.051172
# 8        Turbidity     0.034368
# 7  Trihalomethanes     0.022310
